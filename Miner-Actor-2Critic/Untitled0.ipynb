# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd '/content/drive/My Drive/Miner-Actor-2Critic-fix'
# !pwd
# Out:
# /content/drive/My Drive/Miner-Actor-2Critic-fix
# /content/drive/My Drive/Miner-Actor-2Critic-fix

# %%
# !python main2.py --save_model --batch_size 64 --learning_rate 0.0003 --policy TD3 --limit_obs 2
# Out:
# Streaming output truncated to the last 5000 lines.
# player 3 ---score:  288 --energy:  16
# player 4 ---score:  288 --energy:  16
# Reset game:  ['map4', '2', '0', '50', '100']
# numberOfPlayers:  4
# Episode Num: 2747 Episode T: 5 Reward: -10.000 epsilon:  0.165 terminate: True
# Actor loss =  14.124238 Critic loss =  54.86074
# player 1 ---score:  0 --energy:  0
# player 2 ---score:  0 --energy:  41
# player 3 ---score:  0 --energy:  33
# player 4 ---score:  0 --energy:  32
# Reset game:  ['map4', '20', '5', '50', '100']
# numberOfPlayers:  4
# Episode Num: 2748 Episode T: 1 Reward: -30.000 epsilon:  0.165 terminate: True
# Actor loss =  16.56848 Critic loss =  128.50693
# player 1 ---score:  0 --energy:  50
# player 2 ---score:  0 --energy:  41
# player 3 ---score:  0 --energy:  46
# player 4 ---score:  0 --energy:  46
# Reset game:  ['map2', '5', '1', '50', '100']
# numberOfPlayers:  4
# Episode Num: 2749 Episode T: 5 Reward: -10.000 epsilon:  0.165 terminate: True
# ...
